# %%
pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 43.1 MB/s eta 0:00:00
# ...

# %%
import psycopg2
import pandas as pd

# Подключение к базе данных
conn = psycopg2.connect(
    host="hh-pgsql-public.ebi.ac.uk",
    database="pfmegrnargs",
    user="reader",
    password="NWDMCE5xdipIjRrp"
)

# Получение 10 строк из таблицы rnc_database
cursor = conn.cursor()
cursor.execute("SELECT * FROM rnc_database LIMIT 10")
rows = cursor.fetchall()

# Сохранение данных в DataFrame
df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])

# Сохранение DataFrame в CSV файл
df.to_csv('rnc_database_sample.csv', index=False)

# Получение значений столбцов для 10 строк
cursor.execute("""
SELECT display_name, num_sequences, num_organisms, url
FROM rnc_database
LIMIT 10
""")
selected_columns = cursor.fetchall()

# Закрытие соединения
cursor.close()
conn.close()

print("DataFrame successfully saved to rnc_database_sample.csv")
# Out:
# DataFrame successfully saved to rnc_database.csv
